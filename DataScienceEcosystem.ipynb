# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In my notebook, Data Science Tools and Ecosystem are summarized

# %% [markdown]
# **Objectives:**
#
# - List popular languages for Data Science.
# - Explore common Data Science tools and ecosystems.
# - Using headers in markdown

# %%
# Some of the popular languages that Data Scientists use are:
ordered_list_lang = sorted(['julia', 'python', 'R'])
print(ordered_list_lang)
# Out:
# ['R', 'julia', 'python']

# %%
# Some of the commonly used libraries used by Data Scientists include:
ordered_list_lib = sorted(['sklearn', 'tensorflow', 'pytorch'])
print(ordered_list_lib)
# Out:
# ['pytorch', 'sklearn', 'tensorflow']

# %% [markdown]
# table with the header "Data Science Tools" and three open-source development environment tools used in data science:
#
# | Data Science Tools     |
# |-----------------------|
# | Jupyter Notebook       |
# | RStudio               |
# | Apache Zeppelin       |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This a simple arithmetic expression to mutiply then add integers
res = (3*4)+5
print(res)
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60

def minute_to_hour(minutes):
    return minutes/60

print(minute_to_hour(200))
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Alessio Caponi
